# %% [markdown]
# # Date -> 18-mar-2024
# Evaluation, Regression Matrix
# 1. MAE -> Mean absolute error
# 2. MSE -> Mean square error
# 3. RMSE -> Root mean square error
# 4. R- Square Score
# 5. Adjusted R-square Score (Modified R-square)
#
# MAE = E e=1 to n |y2-y1|/n
# #Advantages of MAE
# 1. It will give you the value in the units of dependent variable.
# 2. It is suitable for the outliers.
# ________________________________________________________________________________
#
# #Disadvantages of MSE
# 1. It is not stable for outliers.
# 2. It will not give the values in the unit of dependent variable.
#
#  RMSE is equal to square root of MSE
#
#  # Advantages of RMSE
#  1.
#
#  #Disadvantage
#  > It is not suitable for the outliers.
#  >
