# %% [markdown]
# St2  Notebook

# %% [markdown]
# # 5 Mar 2024

# %% [markdown]
# # Detect Outliner using z-score
#
# # z_score = (col-neab)/std()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# IQR -> Interquartile Range
# IQR = q3 - q1
# 1,4,4,4,3,6,3,6,3 *italicized text*

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-6-1a166bfd0351> in <cell line: 3>()
#       1 # convert the list into ascending order
#       2 df = np.array([1,4,4,4,3,6,3,6,3 ])
# ----> 3 df.sort_values(ascending = True)
#       4 df
#
# AttributeError: 'numpy.ndarray' object has no attribute 'sort_values'
